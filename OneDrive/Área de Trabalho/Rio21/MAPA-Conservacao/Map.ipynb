# %%
import pandas as pd
import googlemaps
import folium
import warnings
import os
from folium.plugins import MarkerCluster

warnings.filterwarnings('ignore')

# %% [markdown]
# # **Conservação em Andamento**

# %% [markdown]
# Este notebook implementa um pipeline para criar um mapa identificando os pontos do Centro do Rio de Janeiro em que há ocorrências de Conservação em andamento.

# %% [markdown]
# Primeiro, fazemos a leitura do arquivo de dados e selecionamos as colunas que serão utilizadas.

# %%
data = pd.read_excel('../AliancaCentro-Rio/Aliança Centro-Rio 3.0.xlsx')
latlongs = pd.read_excel("../AliancaCentro-Rio/8. LATLONGS/data/ocorrencias.xlsx")

colunas = ['Grau de risco', 'Número do protocolo', 'Status', 'Parecer', 
           'Status 2', 'Parecer 2', 'Endereço', 'Ruas', 'Ponto de referência', 'Serviços',
           'Região', 'Categoria', 'Tipo de ocorrência', 'Agente']

colunas_2 = ['Número do protocolo', 'Latitude', 'Longitude']

data = data[colunas]
latlongs = latlongs[colunas_2]

data = data.merge(latlongs, on='Número do protocolo', how='left')

# %%
flt3 = data["Tipo de ocorrência"] == "Fiscalização de banca de jornal"
BancaDeJornal = data[flt3] # ocorrencias atuais de fiscalização de banca de jornal
BancaDeJornal.to_excel('BancaDeJornal.xlsx')

# %%
# Em andamento na coluna Status ou Em andamento na coluna Status 2
flt = ((data['Status'] == 'Em andamento') | (data['Status 2'] == 'Em andamento'))
EmAndamento = data[flt]

# Conservação na coluna Serviços
flt1 = EmAndamento['Serviços'] == 'Conservação'
flt2 = EmAndamento['Serviços'] == 'Iluminação Pública'

ConservacaoEmAndamento = EmAndamento[flt1] # ocorrencias atuais de conservação em andamento
IluminacaoEmAndamento = EmAndamento[flt2] # ocorrencias atuais de iluminação em andamento

ConservacaoEmAndamento.to_excel('ConservacaoEmAndamento.xlsx')
IluminacaoEmAndamento.to_excel('IluminacaoEmAndamento.xlsx')

# %%
FechadasNaoSolucionadas = data.query("Status == 'Fechado' and Parecer != 'Solucionado' and `Status 2` != 'Em andamento' and `Parecer 2` != 'Solucionado'")

FechadasNaoSolucionadas.sort_values(by = ['Agente', 'Endereço'], inplace = True)
FechadasNaoSolucionadas.reset_index(drop = True, inplace = True)

FechadasNaoSolucionadas.to_excel('FechadasNaoSolucionadas.xlsx')

# %% [markdown]
# ---

# %% [markdown]
# # **Unificando no mesmo DataFrame...**

# %%
ConservacaoEmAndamento.shape
# Out:
# (828, 16)

# %%
FechadasNaoSolucionadas.shape
# Out:
# (400, 16)

# %%
IluminacaoEmAndamento.shape
# Out:
# (2, 16)

# %%
BancaDeJornal.shape
# Out:
# (211, 16)

# %%
tipo = ["Conservação em Andamento"] * len(ConservacaoEmAndamento)
ConservacaoEmAndamento['Tipo'] = tipo

tipo = ["Fechadas Não Solucionadas"] * len(FechadasNaoSolucionadas)
FechadasNaoSolucionadas['Tipo'] = tipo

tipo = ["Iluminação em Andamento"] * len(IluminacaoEmAndamento)
IluminacaoEmAndamento['Tipo'] = tipo

tipo = ["Banca de Jornal"] * len(BancaDeJornal)
BancaDeJornal['Tipo'] = tipo

# %%
# dfCompleto = pd.concat([ConservacaoEmAndamento, IluminacaoEmAndamento, FechadasNaoSolucionadas], ignore_index=True)
dfCompleto = pd.concat([ConservacaoEmAndamento, IluminacaoEmAndamento, FechadasNaoSolucionadas, BancaDeJornal], ignore_index=True)

# %%
dfCompleto.shape
# Out:
# (1441, 17)

# %%
dfCompleto.drop_duplicates(subset='Número do protocolo', keep='first', inplace=True)

# %%
dfCompleto.shape
# Out:
# (1358, 17)

# %% [markdown]
# Agora, é simplesmente gerar o mapa.

# %%
# Conta quantas ocorrências por Endereço (para decidir se agrupa em cluster)
dict_ = dfCompleto["Endereço"].value_counts().to_dict()

# Cria o mapa
mapa = folium.Map(location=[-22.900252, -43.178084], zoom_start=18)

# Título no mapa
title_html = """
<h3 align="center" style="font-size:20px">
  <b>Ocorrências de Conservação ou Iluminação Pública em andamento,<br>
     Fechadas Não Solucionadas ou Bancas de Jornal</b>
</h3>
"""
mapa.get_root().html.add_child(folium.Element(title_html))

# 1) Cria FeatureGroups + MarkerClusters para cada tipo
conservacao_layer = folium.FeatureGroup(name="Conservação em Andamento")
conservacao_cluster = MarkerCluster().add_to(conservacao_layer)

fechadas_layer = folium.FeatureGroup(name="Fechadas Não Solucionadas")
fechadas_cluster = MarkerCluster().add_to(fechadas_layer)

iluminacao_layer = folium.FeatureGroup(name="Iluminação em Andamento")
iluminacao_cluster = MarkerCluster().add_to(iluminacao_layer)

banca_layer = folium.FeatureGroup(name="Banca de Jornal")
banca_cluster = MarkerCluster().add_to(banca_layer)

# %%
for i, row in dfCompleto.iterrows():
    lat = row['Latitude']
    lng = row['Longitude']
    
    # Verifica se as coordenadas são válidas
    if lat is not None and lng is not None:
        tipo = row['Tipo']
        protocolo = row['Número do protocolo']
        endereco = row['Endereço']
        
        # Monta o HTML do popup
        popup_html = f"""
        <b>TIPO:</b> {tipo}<br>
        <b>Protocolo:</b> {protocolo}<br>
        <b>Endereço:</b> {endereco}<br>
        <b>Ponto de referência:</b> {row['Ponto de referência']}<br>
        <b>Grau de risco:</b> {row['Grau de risco']}<br>
        <b>Tipo de ocorrência:</b> {row['Tipo de ocorrência']}<br>
        <b>Serviço:</b> {row['Serviços']}<br>
        <b>Região:</b> {row['Região']}<br>
        <b>Status 1:</b> {row['Status']}<br>
        <b>Parecer:</b> {row['Parecer']}<br>
        <b>Status 2:</b> {row['Status 2']}<br>
        """
        
        # Se existir foto com o nome do protocolo, adiciona ao popup
        for ext in ['.jpeg', '.jpg', '.JPEG', '.JPG']:
            if os.path.isfile(f'fotos/{protocolo}{ext}'):
                popup_html += f"<img src='fotos/{protocolo}{ext}' width='250px'/>"
                break

        popup = folium.Popup(popup_html, max_width=300, min_width=300)
        
        # Escolhe a cor e a camada (cluster) conforme o tipo
        if tipo == "Conservação em Andamento":
            color = 'blue'
            current_cluster = conservacao_cluster
        elif tipo == "Fechadas Não Solucionadas":
            color = 'red'
            current_cluster = fechadas_cluster
        elif tipo == "Iluminação em Andamento":
            color = 'green'
            current_cluster = iluminacao_cluster
        elif tipo == "Banca de Jornal":
            color = 'orange'
            current_cluster = banca_cluster
        else:
            # Se for outro tipo não previsto, pule ou defina um default
            continue
        
        marker = folium.Marker(
            location=[lat, lng],
            popup=popup,
            icon=folium.Icon(color=color)
        )
        
        # Verifica se há mais de 1 ocorrência no mesmo endereço
        # Normalmente, para "agrupar em cluster" independe da contagem,
        # mas se você quiser tratar diferente quando só tem 1 ocorrência, pode
        if dict_[endereco] > 1:
            marker.add_to(current_cluster)
        else:
            # Se só tem 1 ocorrência naquele endereço
            # ainda assim podemos adicionar no cluster para a camada filtrar
            marker.add_to(current_cluster)

# 3) Adiciona cada FeatureGroup (com seu cluster) ao mapa
conservacao_layer.add_to(mapa)
fechadas_layer.add_to(mapa)
iluminacao_layer.add_to(mapa)
banca_layer.add_to(mapa)

# 4) Adiciona o controle de camadas
folium.LayerControl().add_to(mapa)

# Salva o mapa em um arquivo HTML (abra-o no navegador para ver o resultado)
mapa.save("index.html")

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5209314f6427d8fe25c2a27c65d43f31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;
#   &lt;b&gt;Ocorrências de Conservação ou Iluminação Pública em andamento,&lt;br&gt;
#      Fechadas Não Solucionadas ou Bancas de Jornal&lt;/b&gt;
# &lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5209314f6427d8fe25c2a27c65d43f31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5209314f6427d8fe25c2a27c65d43f31 = L.map(
#                 &quot;map_5209314f6427d8fe25c2a27c65d43f31&quot;,
#                 {
#                     center: [-22.900252, -43.178084],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2975c4a6f53237e3c19b3b9be580ef1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f2975c4a6f53237e3c19b3b9be580ef1.addTo(map_5209314f6427d8fe25c2a27c65d43f31);
#
#
#             var feature_group_61c355d89a25324fa660ee1738dc6fee = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_cluster_0d2e2b437ebb1434482d074cee79623b = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_6e3e2f0b17978049a4a99b447836e1f8 = L.marker(
#                 [-22.8944053, -43.1982465],
#                 {}
#             ).addTo(marker_cluster_0d2e2b437ebb1434482d074cee79623b);
#
#
#             var icon_8fdbfe01c33a3b5edd48dbe6d481d7ff = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6e3e2f0b17978049a4a99b447836e1f8.setIcon(icon_8fdbfe01c33a3b5edd48dbe6d481d7ff);
#
#
#         var popup_b28a7950878868975f36b0a48a69d703 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_9e200b27d685ca36e2bc48d40a03ef94 = $(`&lt;div id=&quot;html_9e200b27d685ca36e2bc48d40a03ef94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;TIPO:&lt;/b&gt; Conservação em Andamento&lt;br&gt;         &lt;b&gt;Protocolo:&lt;/b&gt; 23738787-5&lt;br&gt;         &lt;b&gt;Endereço:&lt;/b&gt; Via Binário do Porto, 299&lt;br&gt;         &lt;b&gt;Ponto de referência:&lt;/b&gt; Em frente ao AQWA Corporate - Tishman Speyer&lt;br&gt;         &lt;b&gt;Grau de risco:&lt;/b&gt; 1&lt;br&gt;         &lt;b&gt;Tipo de ocorrência:&lt;/b&gt; Instalação e manutenção de placa de identificação de rua&lt;br&gt;         &lt;b&gt;Serviço:&lt;/b&gt; Conservação&lt;br&gt;         &lt;b&gt;Região:&lt;/b&gt; 1&lt;br&gt;         &lt;b&gt;Status 1:&lt;/b&gt; Fechado&lt;br&gt;         &lt;b&gt;Parecer:&lt;/b&gt; Novo Chamado&lt;br&gt;         &lt;b&gt;Status 2:&lt;/b&gt; Em andamento&lt;br&gt;         &lt;img src=&#x27;fotos/23738787-5.jpeg&#x27; width=&#x27;250px&#x27;/&gt;&lt;/div&gt;`)[0];
#                 popup_b28a7950878868975f36b0a48a69d703.setContent(html_9e200b27d685ca36e2bc48d40a03ef94);
#
#
#
#         marker_6e3e2f0b17978049a4a99b447836e1f8.bindPopup(popup_b28a7950878868975f36b0a48a69d703)
#         ;
#
#
#
#
#             var marker_ae5c8fbf49c53d5103c14d3495d3abf3 = L.marker(
#                 [-22.9063085, -43.1755849],
#                 {}
#             ).addTo(marker_cluster_0d2e2b437ebb1434482d074cee79623b);
#
#
#             var icon_ca46b424585fbd64a92660f4f9a7ab7a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ae5c8fbf49c53d5103c14d3495d3abf3.setIcon(icon_ca46b424585fbd64a92660f4f9a7ab7a);
#
#
#         var popup_a9206d5841dca5a34a39ee3ff7a67beb = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_2da06e638e51e677250c245f4e899548 = $(`&lt;div id=&quot;html_2da06e638e51e677250c245f4e899548&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;TIPO:&lt;/b&gt; Conservação em Andamento&lt;br&gt;         &lt;b&gt;Protocolo:&lt;/b&gt; 23782494-0&lt;br&gt;         &lt;

# %%
# # search for each protocolo in the dataframe in the html file
# found = []
# for i, row in dfCompleto.iterrows():
#     protocolo = str(row['Número do protocolo'])
#     if protocolo in open('index.html').read():
#         found.append(True)
#     else:
#         found.append(False)

# dfCompleto['Found'] = found

# %%
# dfCompleto["Found"].value_counts()

# %%
dfCompleto.shape
# Out:
# (1358, 17)
